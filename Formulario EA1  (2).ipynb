# %% [markdown]
# # Formulario Python para MAT2121

# %% [markdown]
# ## Importar bibliotecas o librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# ## Manipulación de listas

# %%
lista = [1, 2, 3, 4]
primer_elemento = lista[0] #Muestra el 1
ultimo_eleneto = lista[-1] #Muestra el 4

# %% [markdown]
# ## Definición de una función

# %%
def suma(a, b):
    return a + b

# %% [markdown]
# ## Llamar a una función

# %%
resultado = suma(3, 4) # el valor de resultado será 7

# %% [markdown]
# ## Graficar una función

# %%
def f(x):
    return # función a graficar

x = np.arange(valor inicial, valor final, paso)
plt.plot(x, f(x), label = 'f(x)')
plt.title('Nombre del gráfico')
plt.ylabel('Nombre eje y')
plt.xlabel('Nombre eje x')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Encontrar raíces de una función lineal

# %%
def f(x):
    return #'función igualada a cero'

#Valor/es inicial/es de la aproximación
xo = np.linspace(valor inicial, valor final, cantidad de valores del arreglo)
solucion = fsolve(f, xo)
print(f"El valor de la solución es de {solucion[0]}")

# %% [markdown]
# ## Encontrar forma algebraica de una función lineal

# %%
x = np.array([valor 1, valor 2, valor 3, …, valor n])
y = np.array([valor 1, valor 2, valor 3, …, valor n])
#Si la función es de grado 1
pendiente, intercepto = np.polyfit(x, y, 1)
print(f"el valor de la pendiente es de {pendiente:.2f} y el valor del intercepto es de {intercepto:.2f}")

# %% [markdown]
# ## Generar una tabla de datos

# %%
def tabla_datos():
  for i in range(valor inicial,valor final,paso):
    print(f'{i} : {f(i)}')

tabla_datos()

# %% [markdown]
# ## Graficar 2 funciones (con limites en los ejes)

# %%
def f(x):
  return # función N°1 a graficar.

def g(x):
  return # función N°2 a graficar

x = np.arange(valor inicial, valor final, paso)

plt.plot(x, g(x), color = 'r', label = 'g(x)')
plt.plot(x, f(x), color = 'g', label = 'f(x)')
plt.ylim(valor inicial, valor final)
plt.xlim(valor inicial, valor final)

plt.title('Comparación entre las funciones g(x) y f(x)')

plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Intersección de 2 funciones (también sirve al igualar una función a un valor numérico)

# %% [markdown]
# La intersección ocurre cuando.
#
# f(x) = g(x)
#
# 0 = g(x) - f(x)

# %%
#Definiendo la función igualada a cero
def inter(x):
  return g(x)-f(x)

x = np.linspace(valor inicial, valor final, cantidad de valores del arreglo)

#np.around() permite redondear los valores a 2 decimales y elimina los restantes
solucion = np.around(fsolve(inter, x), decimals = 2)

#np.unique() permite eliminar las soluciones repetidas
interseccion = np.unique(solucion)

print(f'Los puntos de intersección de las funciones están en x = {interseccion}')
